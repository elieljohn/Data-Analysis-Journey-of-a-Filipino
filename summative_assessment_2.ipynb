# %% [markdown]
# <a href="https://colab.research.google.com/github/elieljohn/EJ-Malabar-Data-Analyst-Portfolio/blob/main/summative_assessment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Handle Colab Files

# %%
import os
import sys

# Choose the approriate path on Drive that your Notebook is using.

def cf(filename):
    """
    Author: Graham C Roberts
    Concatenates a filename with a directory path and returns the absolute path.
    Preconditions:
    - filename: a string representing the name of the file to be concatenated
      with the directory path.
    Postconditions:
    - Returns a string representing the absolute path of the file after
      concatenation.
    Args:
    filename (str): The name of the file to be concatenated with the
    directory path.
    Returns:
    str: The absolute path of the file after concatenation.
    """
    if 'google.colab' in sys.modules:
        # If running in Colab, return the Colab file path
        from google.colab import drive
        drive.mount('/content/drive')
        # comment out the inappropriate paths
        PATH = '/content/drive/MyDrive/colab_notebooks/summative_assessment_2/'
        # PATH = '/content/drive/MyDrive/colab_notebooks/'
        # PATH = '/content/drive/MyDrive/' # root
        data_dir = os.path.join(PATH, filename.lstrip('/'))
    else:
        # If not running in Colab, return the local file path
        data_dir = os.path.join(os.getcwd(), filename)
    return data_dir

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Convert CSV files to JSON files

# %%
import csv
import json
from datetime import datetime

def csv_to_dict_with_headers(csv_filename):
    '''
    Converts a CSV file to a dictionary of dictionaries.
    Assumes the first row are header fieldnames and uses it as dictionary keys.
    Assumes that the first header is the key to each dictionary. (Ex: member_id, isbn)

    Preconditions:
        csv_filename: A valid CSV file containing data to be converted to a dictionary.

    Postconditions:
        Returns a dictionary of dictionaries containing data from the CSV file.

    Args:
        csv_filename (str): The name of the CSV file to read.

    Returns:
        data_dict: A dictionary of dictionaries.
    '''
    try:
        # Open and read CSV file
        with open(csv_filename, 'r', encoding='utf-8-sig') as file:
            # Read file into a list of dictionaries
            csv_reader = csv.DictReader(file)

            # Convert list to dictionary of dictionaries
            # Create empty dictionary
            data_dict = {}

            # Write each dictionary from csv_reader list as a dictionary in data_dict
            for row in csv_reader:
                key = row[csv_reader.fieldnames[0]]     # First row as key to outer dictionary
                inner_dict = dict(row)                  # Data contained on each dictionary
                data_dict[key] = inner_dict             # Construct each dictionary entry

        return data_dict

    except:
        print("Oops! Something went wrong!")

    finally:
        file.close

def add_availability(books_dict):
    for isbn in books_dict:
        books_dict[isbn]['Available'] = True

def add_fines(members_dict):
    for id in members_dict:
        members_dict[id]['Fines Payable'] = float(0)

def csv_to_list_no_headers(csv_filename, headers):
    '''
    Converts a CSV file to a list of dictionaries.
    Assumes the CSV file has no headers.
    Uses a headers list as inner dictionary keys.

    Preconditions:
        csv_filename: A valid CSV file containing data to be converted to a list.

    Postconditions:
        Returns a list of dictionaries containing data from the CSV file.

    Args:
        csv_filename (str): The name of the CSV file to read.
        headers (list): A list containing the assumed headers to be used as keys.
    Returns:

        data_list: A list of dictionaries.
    '''
    try:
        # Open and read CSV file
        with open(csv_filename, 'r', encoding='utf-8-sig') as file:
            # Read file into a list of dictionaries
            csv_reader = csv.DictReader(file, fieldnames=headers)

            # Convert list to list of dictionaries
            # Create empty list
            data_dict = []

            # Write each dictionary from csv_reader list as a list in data_dict
            for row in csv_reader:
                data_dict.append(row)

        return data_dict

    except:
        print("Oops! Something went wrong!")

    finally:
        file.close

def data_to_json(json_filename, data):
    '''
    Converts a data to a JSON file and prints a success message.
    Otherwise, it prints an error message.

    Preconditions:
        json_filename: A valid file path where the data will be written as a JSON object.
        data: A dictionary or list containing the data to be written as a JSON object.

    Postconditions:
        Creates a JSON file containing the dictionary or list data.

    Args:
        json_filename (str): The name of the JSON file to write.
        data (dict): The name of the dictionary or list to convert to a JSON object.
    '''
    with open(json_filename, 'w') as json_file:
        json.dump(data, json_file, indent=4)
        print("Data saved as JSON file.")

# %%
# Read books_2023.csv to JSON file
# Assign books_2023.csv to filename
csv_filename = cf('books_2023.csv')
# Execute csv_to_dict_with_headers to books_dict
books_dict = csv_to_dict_with_headers(csv_filename)
# Add availability to books_dict
add_availability(books_dict)
# Test print
# print(books_dict)

# Read members_2023.csv to dictionary of dictionaries
# Assign books_2023.csv to filename
csv_filename = cf('members_2023.csv')
# Execute csv_to_dict_with_headers to books_dict
members_dict = csv_to_dict_with_headers(csv_filename)
# Add fines to members_dict
add_fines(members_dict)
# Test print
# print(members_dict)


# Read bookloans_2023.csv to dictionary of dictionaries
# Assign bookloanss_2023.csv to filename
csv_filename = cf('bookloans_2023.csv')
# Create header list for bookloans_2023
headers = ['book_number', 'member_number', 'loan_date_epoch', 'return_date_epoch']
# Execute csv_to_list_no_headers to bookloans_dict
bookloans_list = csv_to_list_no_headers(csv_filename, headers)
# Check if all the books has a return date (all books are returned)
for book in bookloans_list:
    if int(book['return_date_epoch']) == 0:
        print("A book has not yet been returned.")      # Should not print
# Test print
# print(bookloans_dict)

data_to_json(json_filename='members.json', data=members_dict)
data_to_json(json_filename='books.json', data=books_dict)
data_to_json(json_filename='bookloans.json', data=bookloans_list)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Data saved as JSON file.
# Data saved as JSON file.
# Data saved as JSON file.

# %% [markdown]
# ### Provide scan() method for the Book and Member classes

# %% [markdown]
# #### scan() for Book class

# %%
import random

class Book:
    '''
    A class representing a book in the library.

    Attributes:
        isbn (str): The ISBN of the book.
        title (str): The title of the book.
        author (str): The author of the book.
        genre (str): The genre of the book.
        subgenre (str): The subgenre of the book.
        publisher (str): The publisher of the book.
        available (bool): Whether the book is available for loan.

    Methods:
        __init__(self, isbn: str, title: str, author: str, genre: str, subgenre: str, publisher: str)
        scan(): Scans the library for the book requested.
    '''

    def __init__(self, isbn: str, title: str, author: str, genre: str, subgenre: str, publisher: str, available: bool):
        '''
        Initializes a new instance of the Book class.

        Args:
            isbn (str): The ISBN of the book.
            title (str): The title of the book.
            author (str): The author of the book.
            genre (str): The genre of the book.
            subgenre (str): The subgenre of the book.
            publisher (str): The publisher of the book.
        '''
        self.isbn = isbn
        self.title = title
        self.author = author
        self.genre = genre
        self.subgenre = subgenre
        self.publisher = publisher
        self.available = True

    def __str__(self):
        '''
        Returns a string representation of a book.

        Returns:
            str: A string representation of a book, including the ISBN, title, author, genre, and subgenre.
        '''
        return f"ISBN: {self.isbn}\nTitle: {self.title}\nAuthor: {self.author}\nGenre: {self.genre}\nSubgenre: {self.subgenre}\nPublisher: {self.publisher}\nAvailable: {self.available}"

    def scan(json_filename, isbn):
        '''
        Searches for the requested ISBN number from the 'books.json' file.
        Returns the information of the requested book.
        Simulates the scanning of a book's barcode.

        Precondition:
            json_filename: A valid JSON file in a dictionary of dictionaries format containing the information of each book
                in the library's catalogue, where the ISBN is assigned as the key.
            isbn: A valid ISBN that corresponds with an ISBN in the library's catalogue. This is the ISBN being scanned.

        Postcondition:
            Returns the information of the book that matches with the scanned ISBN.

        Args:
            json_filename (str): The name of the JSON filename to read.
            isbn (str): The ISBN number to scan.

        Returns:
            matching_books (list): A list that contains the attributes (information) of the scanned book object.
        '''
        # Create an empty list to store the attributes of the matching scanned book
        matching_book = []

        try:
            # Read the JSON file
            with open(json_filename, 'r') as json_file:
                # Read the JSON file and assign it to data
                data = json.load(json_file)

                # Iterates the matching of each item in data with the scanned ISBN,
                # where book_id is the key and book_info is the value containing an inner dictionary.
                for book_id, book_info in data.items():
                    if book_id == isbn:     # Checks if the current book_id iteration matches with the requested ISBN
                        # Create an instance of a Book using the data from book_info inner dictionary
                        book = Book(
                            isbn=book_info['Number'],
                            title=book_info['Title'],
                            author=book_info['Author'],
                            genre=book_info['Genre'],
                            subgenre=book_info['SubGenre'],
                            publisher=book_info['Publisher'],
                            available=book_info['Available']
                        )
                        matching_book.append(book)      # Append the book to matching_book

        # Specify message for various possible errors
        except FileNotFoundError:
            print("Oops! JSON file not found.")
        except json.JSONDecodeError:
            print("Oops! Invalid JSON format in the file.")
        except:
            print("Oops! Something went wront.")

        return matching_book

def execute_test_book_scan():
    '''
    A test that executes the scan method under the Book class.
    '''
    # Assign 'books.json' to json_filename
    json_filename = 'books.json'

    # Assign a random integer between 1 - 140 as scanned_isbn
    scanned_isbn = str(random.randint(1, 140))

    # Execute the scan method of the Book class using scanned_isbn and assign it to matching_book
    matching_book = Book.scan(json_filename, scanned_isbn)
    # Print the matching information
    for book in matching_book:
        print(book)

execute_test_book_scan()
# Out:
# ISBN: 104
# Title: The World'S Greatest Short Stories
# Author: Unknown
# Genre: Fiction
# Subgenre: Classic
# Publisher: Jaico
# Available: True

# %% [markdown]
# #### scan for Member class

# %%
class Member:
    '''
    A class representing a member of the library.

    Attributes:
        id (str): The unique ID of the member.
        first_name (str): The first name of the member.
        last_name (str): The last name of the member.
        gender (str): The gender of the member.
        email (str): The email address of the member.
        card_number (str): The card number of the member.
        fines (float): The amount of the member's outstanding fines.

    Methods:
        scan()
        generate_card_number()
        issue_membership_card()
    '''
    def __init__(self, id: str, first_name: str, last_name: str, gender: str, email: str, card_number: str, fines: float):
        '''
        Initializes a new Member object.

        Args:
            id (str): The unique ID of the member.
            first_name (str): The first name of the member.
            last_name (str): The last name of the member.
            gender (str): The gender of the member.
            email (str): The email address of the member.
            card_number (str): The card number of the member.
        '''
        self.id = id
        self.first_name = first_name
        self.last_name = last_name
        self.gender = gender
        self.email = email
        self.card_number = card_number
        self.fines = fines

    def __str__(self) -> str:
        '''
        Returns a string representation of the Member object.

        Returns:
            str: A string representation of a member, including the member's ID, name, gender, email, card number.
        '''
        return f"Member ID: {self.id}\nName: {self.first_name} {self.last_name}\nGender: {self.gender}\nEmail: {self.email}\nCard Number: {self.card_number}\nFines: {self.fines}"

    def scan(json_filename, id):
        '''
        Searches for the requested Member ID from the 'members.json' file.
        Returns the information of the requested member.
        Simulates the scanning of a member's card.

        Preconditions:
            json_filename: A valid JSON file in a dictionary of dictionaries format containing the information of each library member.
            id: A valid Member ID that correspond with a Member ID in the library's membership system. This is the Member ID being scanned.

        Postconditions:
            Returns the information of the member that matches with the scanned Member ID.

        Args:
            json_filename (str): The name of the JSON filename to read.
            id (str): The Member ID number to scan.

        Returns:
            matching_member (list): A list that conatins the attributes (information) of the scanned member object.
        '''
        # Create an empty list to store the attributes of the matching scanned member ID
        matching_member = []

        # Read the JSON file
        try:
            with open(json_filename, 'r') as json_file:
                # Read the JSON file and assign it to data
                data = json.load (json_file)

                # Iterates the matching of each item in data with the scanned Member ID,
                # where member_id is the key and member_info is the value containing an inner dictionary.
                for member_id, member_info in data.items():
                    if member_id == id:     # Checks if the current member_id iteration matches with the requested Member ID
                        # Creates an instance of a Member using the data from member_info inner dictionary
                        member = Member(
                            id=member_info['ID'],
                            first_name=member_info['First Name'],
                            last_name=member_info['Last Name'],
                            gender=member_info['Gender'],
                            email=member_info['Email'],
                            card_number=member_info['Card Number'],
                            fines=member_info['Fines Payable']
                        )
                        matching_member.append(member)      # Append the member to matching_member

        # Specify message for various possible errors
        except FileNotFoundError:
            print("Oops! JSON file not found.")
        except json.JSONDecodeError:
            print("Oops! Invalid JSON format in the file.")
        except:
            print("Oops! Something went wrong.")

        return matching_member

def execute_test_member_scan():
    '''
    A test that executes the scan method under the Member class.
    '''
    # Assign 'members.json' to json_filename
    json_filename = 'members.json'

    # Assign a random integer between 1 - 200 as scanned member ID
    scanned_id = str(random.randint(1, 200))

    # Execute the scan method of the Member class using scanned_id and assign it to matching_member
    matching_member = Member.scan(json_filename, scanned_id)
    # Print the matching information
    for member in matching_member:
        print(member)

execute_test_member_scan()
# Out:
# Member ID: 166
# Name: Charlie Elliott
# Gender: Male
# Email: c.elliott@randatmail.com
# Card Number: 166-63
# Fines: 0.0

# %% [markdown]
# ### Provide code that will allow a member to **borrow a book** updating the JSON file

# %%
class Library:
    '''
    A class representing a library.

    Methods:
        __init__(self, name: str)
        add_member()
        add_book()
        loan_book()
        receive_returned_book()
        get_member_card_count()
    '''

    def __init__(self):
        '''
        Initializes a new instance of the Library class.
        '''
        # Create books and members dictionaries
        self.books = {}     # Stores each book object
        self.members = {}   # Stores each member object

    def add_book(self, book):
        '''
        Adds a book from a dictionary.
        '''
        self.books[book.isbn] = book

    def load_books_from_json(self, books_json):
        '''
        Load books from 'books.json' file.

        Parameters:
            books_json (str): A valid JSON file containing a dictionary of books.
        '''
        with open(books_json, 'r') as file:
            books_data = json.load(file)

        self.populate_books_from_json(books_data)       # populate library using data from books_data

    def populate_books_from_json(self, books_data):
        '''
        Populates the library by adding books from the books_data dictionary.

        Parameters:
            books_data (dict): A dictionary containing the data loaded from the books JSON file.
        '''
        # Iterate creating each book from books_data dictionary as a Book object
        for book_data in books_data.values():
            book = Book(
                isbn=book_data['Number'],
                title=book_data['Title'],
                author=book_data['Author'],
                genre=book_data['Genre'],
                subgenre=book_data['SubGenre'],
                publisher=book_data['Publisher'],
                available=book_data['Available']
            )
            # Add each book iteration to the books dictionary under library class
            self.add_book(book)

    def add_member(self, member):
        '''
        Adds a member from a dictionary.
        '''
        self.members[member.id] = member

    def load_members_from_json(self, members_json):
        '''
        Load members from 'members.json' file.

        Parameters:
            members_json (str): A valid JSON file containing a dictionary of members.
        '''
        with open(members_json, 'r') as file:
            members_data = json.load(file)

        self.populate_members_from_json(members_data)       # populate library using data from members_data

    def populate_members_from_json(self, members_data):
        '''
        Populates the library by adding members from the members_data dictionary.

        Parameters:
            members_data (dict): A dictionary containing the data loaded from the members JSON file.
        '''
        # Iterate creating each member from members_data dictionary as a Member object
        for member_data in members_data.values():
            member = Member(
                id=member_data['ID'],
                first_name=member_data['First Name'],
                last_name=member_data['Last Name'],
                gender=member_data['Gender'],
                email=member_data['Email'],
                card_number=member_data['Card Number'],
                fines=member_data['Fines Payable'],
            )
            # Add each member iteration to the members dictionary under library class
            self.add_member(member)

    def loan_book(self, id: str, isbn: str, loan_date_epoch: int) -> bool:
        '''
        Loans a book to a member of the library.
        Args:
            id (str): The ID number of the member borrowing the book.
            isbn (str): The ISBN of the book being borrowed.

        Returns:
            bool: True if the book was successfully loaned, if not it returns False.
        '''
        # Check if Member ID is valid
        if id not in self.members:
            return False

        # Check if ISBN is valid
        if isbn not in self.books:
            return False

        # Check if book is currently available
        if not self.books[isbn].available:
            return False

        # Add books borrowed to the member who borrowed the book in members_dict
        if 'Books Borrowed' not in self.members[id]:
            self.members[id]['Books Borrowed'] = []

        # Add borrowed book to 'Books Borrowed'
        self.members[id]['Books Borrowed'].append(isbn)

        # Update 'members.json' from the updated members_dict
        data_to_json(json_filename='members.json', data=self.members)

        # Add book loan entry to bookloans_list
        return_date_epoch = 0       # Will be updated when book is returned
        book_loan = {
            'book_number': isbn,
            'member_number': id,
            'loan_date_epoch': loan_date_epoch,
            'return_date_epoch': return_date_epoch
        }
        self.bookloans_list.append(book_loan)

        # Update bookloans.json from the updated bookloans_list
        data_to_json(json_filename='bookloans.json', data=self.bookloans_list)

        # Update book as unavailable
        self.books[isbn].available = False

        return True

# %%
library = Library()

books_json = 'books.json'
library.load_books_from_json(books_json)

members_json = 'members.json'
library.load_members_from_json(members_json)

# Test prints
# Access library members by ID
for id, member in library.members.items():
    print(f"{member}\n-------")

# Access library books by ISBN
#for isbn, book in library.books.items():
#    print(f"{book}\n-------")
# Out:
# Member ID: 1
# Name: Adelaide Cunningham
# Gender: Female
# Email: a.cunningham@randatmail.com
# Card Number: 1-13
# Fines: 0.0
# -------
# Member ID: 2
# Name: Charlie Roberts
# Gender: Male
# Email: c.roberts@randatmail.com
# Card Number: 2-22
# Fines: 0.0
# -------
# Member ID: 3
# Name: Eric Cooper
# Gender: Male
# Email: e.cooper@randatmail.com
# Card Number: 3-33
# Fines: 0.0
# -------
# Member ID: 4
# Name: Cadie Hall
# Gender: Female
# Email: c.hall@randatmail.com
# Card Number: 4-43
# Fines: 0.0
# -------
# Member ID: 5
# Name: Darcy Howard
# Gender: Female
# Email: d.howard@randatmail.com
# Card Number: 5-52
# Fines: 0.0
# -------
# Member ID: 6
# Name: Connie West
# Gender: Female
# Email: c.west@randatmail.com
# Card Number: 6-61
# Fines: 0.0
# -------
# Member ID: 7
# Name: Lyndon Ellis
# Gender: Male
# Email: l.ellis@randatmail.com
# Card Number: 7-72
# Fines: 0.0
# -------
# Member ID: 8
# Name: Amy Hamilton
# Gender: Female
# Email: a.hamilton@randatmail.com
# Card Number: 8-82
# Fines: 0.0
# -------
# Member ID: 9
# Name: Kelvin Wilson
# Gender: Male
# Email: k.wilson@randatmail.com
# Card Number: 9-93
# Fines: 0.0
# -------
# Member ID: 10
# Name: Arianna Watson
# Gender: Female
# Email: a.watson@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 11
# Name: Lydia Farrell
# Gender: Female
# Email: l.farrell@randatmail.com
# Card Number: 11-13
# Fines: 0.0
# -------
# Member ID: 12
# Name: Ada Harris
# Gender: Female
# Email: a.harris@randatmail.com
# Card Number: 12-22
# Fines: 0.0
# -------
# Member ID: 13
# Name: Sarah Wilson
# Gender: Female
# Email: s.wilson@randatmail.com
# Card Number: 13-31
# Fines: 0.0
# -------
# Member ID: 14
# Name: Nicole Phillips
# Gender: Female
# Email: n.phillips@randatmail.com
# Card Number: 14-43
# Fines: 0.0
# -------
# Member ID: 15
# Name: Maddie Anderson
# Gender: Female
# Email: m.anderson@randatmail.com
# Card Number: 15-53
# Fines: 0.0
# -------
# Member ID: 16
# Name: Brad Alexander
# Gender: Male
# Email: b.alexander@randatmail.com
# Card Number: 16-61
# Fines: 0.0
# -------
# Member ID: 17
# Name: Lucia Spencer
# Gender: Female
# Email: l.spencer@randatmail.com
# Card Number: 17-72
# Fines: 0.0
# -------
# Member ID: 18
# Name: Freddie Ellis
# Gender: Male
# Email: f.ellis@randatmail.com
# Card Number: 18-83
# Fines: 0.0
# -------
# Member ID: 19
# Name: Hailey Moore
# Gender: Female
# Email: h.moore@randatmail.com
# Card Number: 19-92
# Fines: 0.0
# -------
# Member ID: 20
# Name: Kelsey Morrison
# Gender: Female
# Email: k.morrison@randatmail.com
# Card Number: 20-2
# Fines: 0.0
# -------
# Member ID: 21
# Name: Elise Russell
# Gender: Female
# Email: e.russell@randatmail.com
# Card Number: 21-13
# Fines: 0.0
# -------
# Member ID: 22
# Name: Mike Crawford
# Gender: Male
# Email: m.crawford@randatmail.com
# Card Number: 22-23
# Fines: 0.0
# -------
# Member ID: 23
# Name: Amy Murray
# Gender: Female
# Email: a.murray@randatmail.com
# Card Number: 23-32
# Fines: 0.0
# -------
# Member ID: 24
# Name: Amanda Gray
# Gender: Female
# Email: a.gray@randatmail.com
# Card Number: 24-42
# Fines: 0.0
# -------
# Member ID: 25
# Name: Myra Morgan
# Gender: Female
# Email: m.morgan@randatmail.com
# Card Number: 25-51
# Fines: 0.0
# -------
# Member ID: 26
# Name: Miley Rogers
# Gender: Female
# Email: m.rogers@randatmail.com
# Card Number: 26-63
# Fines: 0.0
# -------
# Member ID: 27
# Name: Kate Morrison
# Gender: Female
# Email: k.morrison@randatmail.com
# Card Number: 27-72
# Fines: 0.0
# -------
# Member ID: 28
# Name: Luke Craig
# Gender: Male
# Email: l.craig@randatmail.com
# Card Number: 28-81
# Fines: 0.0
# -------
# Member ID: 29
# Name: Michael Miller
# Gender: Male
# Email: m.miller@randatmail.com
# Card Number: 29-92
# Fines: 0.0
# -------
# Member ID: 30
# Name: Paige Elliott
# Gender: Female
# Email: p.elliott@randatmail.com
# Card Number: 30-1
# Fines: 0.0
# -------
# Member ID: 31
# Name: Gianna Warren
# Gender: Female
# Email: g.warren@randatmail.com
# Card Number: 31-13
# Fines: 0.0
# -------
# Member ID: 32
# Name: Lydia Campbell
# Gender: Female
# Email: l.campbell@randatmail.com
# Card Number: 32-22
# Fines: 0.0
# -------
# Member ID: 33
# Name: Anna Barrett
# Gender: Female
# Email: a.barrett@randatmail.com
# Card Number: 33-32
# Fines: 0.0
# -------
# Member ID: 34
# Name: Connie Phillips
# Gender: Female
# Email: c.phillips@randatmail.com
# Card Number: 34-43
# Fines: 0.0
# -------
# Member ID: 35
# Name: Briony Mason
# Gender: Female
# Email: b.mason@randatmail.com
# Card Number: 35-51
# Fines: 0.0
# -------
# Member ID: 36
# Name: Lucy Morrison
# Gender: Female
# Email: l.morrison@randatmail.com
# Card Number: 36-63
# Fines: 0.0
# -------
# Member ID: 37
# Name: Deanna Higgins
# Gender: Female
# Email: d.higgins@randatmail.com
# Card Number: 37-71
# Fines: 0.0
# -------
# Member ID: 38
# Name: David Richards
# Gender: Male
# Email: d.richards@randatmail.com
# Card Number: 38-83
# Fines: 0.0
# -------
# Member ID: 39
# Name: Ada Brown
# Gender: Female
# Email: a.brown@randatmail.com
# Card Number: 39-92
# Fines: 0.0
# -------
# Member ID: 40
# Name: Maria Thomas
# Gender: Female
# Email: m.thomas@randatmail.com
# Card Number: 40-2
# Fines: 0.0
# -------
# Member ID: 41
# Name: Fiona Walker
# Gender: Female
# Email: f.walker@randatmail.com
# Card Number: 41-12
# Fines: 0.0
# -------
# Member ID: 42
# Name: Alisa Harris
# Gender: Female
# Email: a.harris@randatmail.com
# Card Number: 42-22
# Fines: 0.0
# -------
# Member ID: 43
# Name: Kate Harris
# Gender: Female
# Email: k.harris@randatmail.com
# Card Number: 43-31
# Fines: 0.0
# -------
# Member ID: 44
# Name: Cadie Roberts
# Gender: Female
# Email: c.roberts@randatmail.com
# Card Number: 44-42
# Fines: 0.0
# -------
# Member ID: 45
# Name: Ryan Montgomery
# Gender: Male
# Email: r.montgomery@randatmail.com
# Card Number: 45-51
# Fines: 0.0
# -------
# Member ID: 46
# Name: Henry Henderson
# Gender: Male
# Email: h.henderson@randatmail.com
# Card Number: 46-62
# Fines: 0.0
# -------
# Member ID: 47
# Name: Sabrina West
# Gender: Female
# Email: s.west@randatmail.com
# Card Number: 47-73
# Fines: 0.0
# -------
# Member ID: 48
# Name: Adison Murphy
# Gender: Male
# Email: a.murphy@randatmail.com
# Card Number: 48-83
# Fines: 0.0
# -------
# Member ID: 49
# Name: Adison Ellis
# Gender: Male
# Email: a.ellis@randatmail.com
# Card Number: 49-91
# Fines: 0.0
# -------
# Member ID: 50
# Name: Adrianna Walker
# Gender: Female
# Email: a.walker@randatmail.com
# Card Number: 50-3
# Fines: 0.0
# -------
# Member ID: 51
# Name: Miranda Hill
# Gender: Female
# Email: m.hill@randatmail.com
# Card Number: 51-12
# Fines: 0.0
# -------
# Member ID: 52
# Name: Jasmine Tucker
# Gender: Female
# Email: j.tucker@randatmail.com
# Card Number: 52-21
# Fines: 0.0
# -------
# Member ID: 53
# Name: Jack Alexander
# Gender: Male
# Email: j.alexander@randatmail.com
# Card Number: 53-33
# Fines: 0.0
# -------
# Member ID: 54
# Name: David Lloyd
# Gender: Male
# Email: d.lloyd@randatmail.com
# Card Number: 54-42
# Fines: 0.0
# -------
# Member ID: 55
# Name: Sofia Montgomery
# Gender: Female
# Email: s.montgomery@randatmail.com
# Card Number: 55-52
# Fines: 0.0
# -------
# Member ID: 56
# Name: Alisa Wilson
# Gender: Female
# Email: a.wilson@randatmail.com
# Card Number: 56-62
# Fines: 0.0
# -------
# Member ID: 57
# Name: Deanna Richardson
# Gender: Female
# Email: d.richardson@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 58
# Name: Sydney Miller
# Gender: Female
# Email: s.miller@randatmail.com
# Card Number: 58-82
# Fines: 0.0
# -------
# Member ID: 59
# Name: Spike Jones
# Gender: Male
# Email: s.jones@randatmail.com
# Card Number: 59-92
# Fines: 0.0
# -------
# Member ID: 60
# Name: Ashton Barrett
# Gender: Male
# Email: a.barrett@randatmail.com
# Card Number: 60-3
# Fines: 0.0
# -------
# Member ID: 61
# Name: Reid Kelley
# Gender: Male
# Email: r.kelley@randatmail.com
# Card Number: 61-12
# Fines: 0.0
# -------
# Member ID: 62
# Name: Ellia Smith
# Gender: Female
# Email: e.smith@randatmail.com
# Card Number: 62-22
# Fines: 0.0
# -------
# Member ID: 63
# Name: Jacob Wright
# Gender: Male
# Email: j.wright@randatmail.com
# Card Number: 63-32
# Fines: 0.0
# -------
# Member ID: 64
# Name: Darcy Morris
# Gender: Female
# Email: d.morris@randatmail.com
# Card Number: 64-41
# Fines: 0.0
# -------
# Member ID: 65
# Name: Naomi Johnson
# Gender: Female
# Email: n.johnson@randatmail.com
# Card Number: 65-51
# Fines: 0.0
# -------
# Member ID: 66
# Name: Reid Richardson
# Gender: Male
# Email: r.richardson@randatmail.com
# Card Number: 66-62
# Fines: 0.0
# -------
# Member ID: 67
# Name: Daryl Foster
# Gender: Male
# Email: d.foster@randatmail.com
# Card Number: 67-72
# Fines: 0.0
# -------
# Member ID: 68
# Name: Adam Carter
# Gender: Male
# Email: a.carter@randatmail.com
# Card Number: 68-83
# Fines: 0.0
# -------
# Member ID: 69
# Name: Abraham Cooper
# Gender: Male
# Email: a.cooper@randatmail.com
# Card Number: 69-92
# Fines: 0.0
# -------
# Member ID: 70
# Name: Heather Riley
# Gender: Female
# Email: h.riley@randatmail.com
# Card Number: 70-1
# Fines: 0.0
# -------
# Member ID: 71
# Name: Miller Cameron
# Gender: Male
# Email: m.cameron@randatmail.com
# Card Number: 71-13
# Fines: 0.0
# -------
# Member ID: 72
# Name: Deanna Myers
# Gender: Female
# Email: d.myers@randatmail.com
# Card Number: 72-22
# Fines: 0.0
# -------
# Member ID: 73
# Name: Stuart Andrews
# Gender: Male
# Email: s.andrews@randatmail.com
# Card Number: 73-33
# Fines: 0.0
# -------
# Member ID: 74
# Name: Oscar Ferguson
# Gender: Male
# Email: o.ferguson@randatmail.com
# Card Number: 74-42
# Fines: 0.0
# -------
# Member ID: 75
# Name: Amelia Morgan
# Gender: Female
# Email: a.morgan@randatmail.com
# Card Number: 75-53
# Fines: 0.0
# -------
# Member ID: 76
# Name: Tiana Russell
# Gender: Female
# Email: t.russell@randatmail.com
# Card Number: 76-63
# Fines: 0.0
# -------
# Member ID: 77
# Name: Myra Martin
# Gender: Female
# Email: m.martin@randatmail.com
# Card Number: 77-73
# Fines: 0.0
# -------
# Member ID: 78
# Name: Lucy Richards
# Gender: Female
# Email: l.richards@randatmail.com
# Card Number: 78-82
# Fines: 0.0
# -------
# Member ID: 79
# Name: Jack Evans
# Gender: Male
# Email: j.evans@randatmail.com
# Card Number: 79-91
# Fines: 0.0
# -------
# Member ID: 80
# Name: Catherine Ferguson
# Gender: Female
# Email: c.ferguson@randatmail.com
# Card Number: 80-3
# Fines: 0.0
# -------
# Member ID: 81
# Name: Bruce Hunt
# Gender: Male
# Email: b.hunt@randatmail.com
# Card Number: 81-12
# Fines: 0.0
# -------
# Member ID: 82
# Name: Tony Moore
# Gender: Male
# Email: t.moore@randatmail.com
# Card Number: 82-22
# Fines: 0.0
# -------
# Member ID: 83
# Name: Alissa Payne
# Gender: Female
# Email: a.payne@randatmail.com
# Card Number: 83-31
# Fines: 0.0
# -------
# Member ID: 84
# Name: Arthur Anderson
# Gender: Male
# Email: a.anderson@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 85
# Name: Aldus Carroll
# Gender: Male
# Email: a.carroll@randatmail.com
# Card Number: 85-53
# Fines: 0.0
# -------
# Member ID: 86
# Name: Paige Andrews
# Gender: Female
# Email: p.andrews@randatmail.com
# Card Number: 86-61
# Fines: 0.0
# -------
# Member ID: 87
# Name: Melanie Cameron
# Gender: Female
# Email: m.cameron@randatmail.com
# Card Number: 87-71
# Fines: 0.0
# -------
# Member ID: 88
# Name: Adele Barnes
# Gender: Female
# Email: a.barnes@randatmail.com
# Card Number: 88-82
# Fines: 0.0
# -------
# Member ID: 89
# Name: Adam Elliott
# Gender: Male
# Email: a.elliott@randatmail.com
# Card Number: 89-91
# Fines: 0.0
# -------
# Member ID: 90
# Name: Adam Farrell
# Gender: Male
# Email: a.farrell@randatmail.com
# Card Number: 90-1
# Fines: 0.0
# -------
# Member ID: 91
# Name: William Lloyd
# Gender: Male
# Email: w.lloyd@randatmail.com
# Card Number: 91-13
# Fines: 0.0
# -------
# Member ID: 92
# Name: Victor Ferguson
# Gender: Male
# Email: v.ferguson@randatmail.com
# Card Number: 92-23
# Fines: 0.0
# -------
# Member ID: 93
# Name: Alan Phillips
# Gender: Male
# Email: a.phillips@randatmail.com
# Card Number: 93-32
# Fines: 0.0
# -------
# Member ID: 94
# Name: George Allen
# Gender: Male
# Email: g.allen@randatmail.com
# Card Number: 94-43
# Fines: 0.0
# -------
# Member ID: 95
# Name: Jared Hill
# Gender: Male
# Email: j.hill@randatmail.com
# Card Number: 95-51
# Fines: 0.0
# -------
# Member ID: 96
# Name: Catherine Myers
# Gender: Female
# Email: c.myers@randatmail.com
# Card Number: 96-61
# Fines: 0.0
# -------
# Member ID: 97
# Name: Alexia Robinson
# Gender: Female
# Email: a.robinson@randatmail.com
# Card Number: 97-72
# Fines: 0.0
# -------
# Member ID: 98
# Name: Lucia Miller
# Gender: Female
# Email: l.miller@randatmail.com
# Card Number: 98-81
# Fines: 0.0
# -------
# Member ID: 99
# Name: Abraham Mason
# Gender: Male
# Email: a.mason@randatmail.com
# Card Number: 99-91
# Fines: 0.0
# -------
# Member ID: 100
# Name: Connie Gibson
# Gender: Female
# Email: c.gibson@randatmail.com
# Card Number: 100-3
# Fines: 0.0
# -------
# Member ID: 101
# Name: Abigail Lloyd
# Gender: Female
# Email: a.lloyd@randatmail.com
# Card Number: 101-11
# Fines: 0.0
# -------
# Member ID: 102
# Name: Miranda Richardson
# Gender: Female
# Email: m.richardson@randatmail.com
# Card Number: 102-21
# Fines: 0.0
# -------
# Member ID: 103
# Name: Alen Murphy
# Gender: Male
# Email: a.murphy@randatmail.com
# Card Number: 103-32
# Fines: 0.0
# -------
# Member ID: 104
# Name: Arthur Andrews
# Gender: Male
# Email: a.andrews@randatmail.com
# Card Number: 104-43
# Fines: 0.0
# -------
# Member ID: 105
# Name: Clark Stewart
# Gender: Male
# Email: c.stewart@randatmail.com
# Card Number: 105-53
# Fines: 0.0
# -------
# Member ID: 106
# Name: Abigail Myers
# Gender: Female
# Email: a.myers@randatmail.com
# Card Number: 106-63
# Fines: 0.0
# -------
# Member ID: 107
# Name: Briony Edwards
# Gender: Female
# Email: b.edwards@randatmail.com
# Card Number: 107-73
# Fines: 0.0
# -------
# Member ID: 108
# Name: Sophia Russell
# Gender: Female
# Email: s.russell@randatmail.com
# Card Number: 108-82
# Fines: 0.0
# -------
# Member ID: 109
# Name: Jenna Clark
# Gender: Female
# Email: j.clark@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 110
# Name: Maria Crawford
# Gender: Female
# Email: m.crawford@randatmail.com
# Card Number: 110-1
# Fines: 0.0
# -------
# Member ID: 111
# Name: Arthur Wells
# Gender: Male
# Email: a.wells@randatmail.com
# Card Number: 111-12
# Fines: 0.0
# -------
# Member ID: 112
# Name: Abraham Armstrong
# Gender: Male
# Email: a.armstrong@randatmail.com
# Card Number: 112-21
# Fines: 0.0
# -------
# Member ID: 113
# Name: Samantha Mason
# Gender: Female
# Email: s.mason@randatmail.com
# Card Number: 113-32
# Fines: 0.0
# -------
# Member ID: 114
# Name: Rubie Thompson
# Gender: Female
# Email: r.thompson@randatmail.com
# Card Number: 114-43
# Fines: 0.0
# -------
# Member ID: 115
# Name: Sabrina Foster
# Gender: Female
# Email: s.foster@randatmail.com
# Card Number: 115-52
# Fines: 0.0
# -------
# Member ID: 116
# Name: Miranda Howard
# Gender: Female
# Email: m.howard@randatmail.com
# Card Number: 116-61
# Fines: 0.0
# -------
# Member ID: 117
# Name: Valeria Montgomery
# Gender: Female
# Email: v.montgomery@randatmail.com
# Card Number: 117-72
# Fines: 0.0
# -------
# Member ID: 118
# Name: Aldus Carter
# Gender: Male
# Email: a.carter@randatmail.com
# Card Number: 118-81
# Fines: 0.0
# -------
# Member ID: 119
# Name: Frederick Evans
# Gender: Male
# Email: f.evans@randatmail.com
# Card Number: 119-91
# Fines: 0.0
# -------
# Member ID: 120
# Name: Eleanor Douglas
# Gender: Female
# Email: e.douglas@randatmail.com
# Card Number: 120-1
# Fines: 0.0
# -------
# Member ID: 121
# Name: Wilson Higgins
# Gender: Male
# Email: w.higgins@randatmail.com
# Card Number: 121-11
# Fines: 0.0
# -------
# Member ID: 122
# Name: Paige Kelley
# Gender: Female
# Email: p.kelley@randatmail.com
# Card Number: 122-23
# Fines: 0.0
# -------
# Member ID: 123
# Name: Amber Brooks
# Gender: Female
# Email: a.brooks@randatmail.com
# Card Number: 123-31
# Fines: 0.0
# -------
# Member ID: 124
# Name: Preston Payne
# Gender: Male
# Email: p.payne@randatmail.com
# Card Number: 124-42
# Fines: 0.0
# -------
# Member ID: 125
# Name: Ashton Hill
# Gender: Male
# Email: a.hill@randatmail.com
# Card Number: 125-51
# Fines: 0.0
# -------
# Member ID: 126
# Name: Madaline Roberts
# Gender: Female
# Email: m.roberts@randatmail.com
# Card Number: 126-62
# Fines: 0.0
# -------
# Member ID: 127
# Name: Lucy Richardson
# Gender: Female
# Email: l.richardson@randatmail.com
# Card Number: 127-72
# Fines: 0.0
# -------
# Member ID: 128
# Name: Aiden Moore
# Gender: Male
# Email: a.moore@randatmail.com
# Card Number: 128-83
# Fines: 0.0
# -------
# Member ID: 129
# Name: Mary Ellis
# Gender: Female
# Email: m.ellis@randatmail.com
# Card Number: 129-92
# Fines: 0.0
# -------
# Member ID: 130
# Name: Joyce Baker
# Gender: Female
# Email: j.baker@randatmail.com
# Card Number: 130-3
# Fines: 0.0
# -------
# Member ID: 131
# Name: Miller Moore
# Gender: Male
# Email: m.moore@randatmail.com
# Card Number: 131-11
# Fines: 0.0
# -------
# Member ID: 132
# Name: Michelle Morrison
# Gender: Female
# Email: m.morrison@randatmail.com
# Card Number: 132-22
# Fines: 0.0
# -------
# Member ID: 133
# Name: Sydney Taylor
# Gender: Female
# Email: s.taylor@randatmail.com
# Card Number: 133-32
# Fines: 0.0
# -------
# Member ID: 134
# Name: Jacob Cooper
# Gender: Male
# Email: j.cooper@randatmail.com
# Card Number: 134-41
# Fines: 0.0
# -------
# Member ID: 135
# Name: Harold Myers
# Gender: Male
# Email: h.myers@randatmail.com
# Card Number: 135-52
# Fines: 0.0
# -------
# Member ID: 136
# Name: Justin Montgomery
# Gender: Male
# Email: j.montgomery@randatmail.com
# Card Number: 136-62
# Fines: 0.0
# -------
# Member ID: 137
# Name: Justin Thompson
# Gender: Male
# Email: j.thompson@randatmail.com
# Card Number: 137-73
# Fines: 0.0
# -------
# Member ID: 138
# Name: Daryl Watson
# Gender: Male
# Email: d.watson@randatmail.com
# Card Number: 138-83
# Fines: 0.0
# -------
# Member ID: 139
# Name: Tara Barrett
# Gender: Female
# Email: t.barrett@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 140
# Name: Arianna Barnes
# Gender: Female
# Email: a.barnes@randatmail.com
# Card Number: 140-3
# Fines: 0.0
# -------
# Member ID: 141
# Name: Kirsten Harper
# Gender: Female
# Email: k.harper@randatmail.com
# Card Number: 141-13
# Fines: 0.0
# -------
# Member ID: 142
# Name: Valeria Barnes
# Gender: Female
# Email: v.barnes@randatmail.com
# Card Number: 142-21
# Fines: 0.0
# -------
# Member ID: 143
# Name: Chloe Barnes
# Gender: Female
# Email: c.barnes@randatmail.com
# Card Number: 143-33
# Fines: 0.0
# -------
# Member ID: 144
# Name: Alexia Moore
# Gender: Female
# Email: a.moore@randatmail.com
# Card Number: 144-43
# Fines: 0.0
# -------
# Member ID: 145
# Name: Roman Hunt
# Gender: Male
# Email: r.hunt@randatmail.com
# Card Number: 145-51
# Fines: 0.0
# -------
# Member ID: 146
# Name: Charlie Higgins
# Gender: Male
# Email: c.higgins@randatmail.com
# Card Number: 146-62
# Fines: 0.0
# -------
# Member ID: 147
# Name: Vanessa Dixon
# Gender: Female
# Email: v.dixon@randatmail.com
# Card Number: 147-73
# Fines: 0.0
# -------
# Member ID: 148
# Name: William Warren
# Gender: Male
# Email: w.warren@randatmail.com
# Card Number: 148-81
# Fines: 0.0
# -------
# Member ID: 149
# Name: Olivia Alexander
# Gender: Female
# Email: o.alexander@randatmail.com
# Card Number: 149-93
# Fines: 0.0
# -------
# Member ID: 150
# Name: Daniel Foster
# Gender: Male
# Email: d.foster@randatmail.com
# Card Number: 150-2
# Fines: 0.0
# -------
# Member ID: 151
# Name: Lydia Robinson
# Gender: Female
# Email: l.robinson@randatmail.com
# Card Number: 151-12
# Fines: 0.0
# -------
# Member ID: 152
# Name: Amelia Moore
# Gender: Female
# Email: a.moore@randatmail.com
# Card Number: 152-22
# Fines: 0.0
# -------
# Member ID: 153
# Name: Lucia Morgan
# Gender: Female
# Email: l.morgan@randatmail.com
# Card Number: 153-33
# Fines: 0.0
# -------
# Member ID: 154
# Name: Darcy Wright
# Gender: Female
# Email: d.wright@randatmail.com
# Card Number: 154-43
# Fines: 0.0
# -------
# Member ID: 155
# Name: Dainton Chapman
# Gender: Male
# Email: d.chapman@randatmail.com
# Card Number: 155-52
# Fines: 0.0
# -------
# Member ID: 156
# Name: Penelope Roberts
# Gender: Female
# Email: p.roberts@randatmail.com
# Card Number: 156-63
# Fines: 0.0
# -------
# Member ID: 157
# Name: Kellan Mason
# Gender: Male
# Email: k.mason@randatmail.com
# Card Number: 157-72
# Fines: 0.0
# -------
# Member ID: 158
# Name: Owen Ferguson
# Gender: Male
# Email: o.ferguson@randatmail.com
# Card Number: 158-83
# Fines: 0.0
# -------
# Member ID: 159
# Name: Elise Walker
# Gender: Female
# Email: e.walker@randatmail.com
# Card Number: 159-93
# Fines: 0.0
# -------
# Member ID: 160
# Name: David Hamilton
# Gender: Male
# Email: d.hamilton@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 161
# Name: Dominik Gray
# Gender: Male
# Email: d.gray@randatmail.com
# Card Number: 161-12
# Fines: 0.0
# -------
# Member ID: 162
# Name: Violet Thomas
# Gender: Female
# Email: v.thomas@randatmail.com
# Card Number: 162-23
# Fines: 0.0
# -------
# Member ID: 163
# Name: Aston Crawford
# Gender: Male
# Email: a.crawford@randatmail.com
# Card Number: 163-31
# Fines: 0.0
# -------
# Member ID: 164
# Name: Rebecca Morris
# Gender: Female
# Email: r.morris@randatmail.com
# Card Number: 164-43
# Fines: 0.0
# -------
# Member ID: 165
# Name: Connie Campbell
# Gender: Female
# Email: c.campbell@randatmail.com
# Card Number: 165-51
# Fines: 0.0
# -------
# Member ID: 166
# Name: Charlie Elliott
# Gender: Male
# Email: c.elliott@randatmail.com
# Card Number: 166-63
# Fines: 0.0
# -------
# Member ID: 167
# Name: Alissa Ferguson
# Gender: Female
# Email: a.ferguson@randatmail.com
# Card Number: 167-71
# Fines: 0.0
# -------
# Member ID: 168
# Name: Jasmine Davis
# Gender: Female
# Email: j.davis@randatmail.com
# Card Number: 168-83
# Fines: 0.0
# -------
# Member ID: 169
# Name: Aida Harrison
# Gender: Female
# Email: a.harrison@randatmail.com
# Card Number: 169-93
# Fines: 0.0
# -------
# Member ID: 170
# Name: Marcus Davis
# Gender: Male
# Email: m.davis@randatmail.com
# Card Number: 170-2
# Fines: 0.0
# -------
# Member ID: 171
# Name: Walter Craig
# Gender: Male
# Email: w.craig@randatmail.com
# Card Number: 171-13
# Fines: 0.0
# -------
# Member ID: 172
# Name: Lucas Howard
# Gender: Male
# Email: l.howard@randatmail.com
# Card Number: 172-22
# Fines: 0.0
# -------
# Member ID: 173
# Name: Isabella Miller
# Gender: Female
# Email: i.miller@randatmail.com
# Card Number: 173-31
# Fines: 0.0
# -------
# Member ID: 174
# Name: Rubie Allen
# Gender: Female
# Email: r.allen@randatmail.com
# Card Number: 174-41
# Fines: 0.0
# -------
# Member ID: 175
# Name: Kelsey Spencer
# Gender: Female
# Email: k.spencer@randatmail.com
# Card Number: 175-52
# Fines: 0.0
# -------
# Member ID: 176
# Name: Dainton Parker
# Gender: Male
# Email: d.parker@randatmail.com
# Card Number: 176-63
# Fines: 0.0
# -------
# Member ID: 177
# Name: Kevin Adams
# Gender: Male
# Email: k.adams@randatmail.com
# Card Number: 177-73
# Fines: 0.0
# -------
# Member ID: 178
# Name: Derek Campbell
# Gender: Male
# Email: d.campbell@randatmail.com
# Card Number: 178-82
# Fines: 0.0
# -------
# Member ID: 179
# Name: James Richardson
# Gender: Male
# Email: j.richardson@randatmail.com
# Card Number: 179-92
# Fines: 0.0
# -------
# Member ID: 180
# Name: Roland Johnson
# Gender: Male
# Email: r.johnson@randatmail.com
# Card Number: 180-2
# Fines: 0.0
# -------
# Member ID: 181
# Name: Melissa Walker
# Gender: Female
# Email: m.walker@randatmail.com
# Card Number: 181-12
# Fines: 0.0
# -------
# Member ID: 182
# Name: William Kelly
# Gender: Male
# Email: w.kelly@randatmail.com
# Card Number: 182-22
# Fines: 0.0
# -------
# Member ID: 183
# Name: Melanie Williams
# Gender: Female
# Email: m.williams@randatmail.com
# Card Number: 183-32
# Fines: 0.0
# -------
# Member ID: 184
# Name: Martin Morris
# Gender: Male
# Email: m.morris@randatmail.com
# Card Number: 184-42
# Fines: 0.0
# -------
# Member ID: 185
# Name: Robert Cunningham
# Gender: Male
# Email: r.cunningham@randatmail.com
# Card Number: 185-53
# Fines: 0.0
# -------
# Member ID: 186
# Name: Albert Roberts
# Gender: Male
# Email: a.roberts@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 187
# Name: Olivia Cameron
# Gender: Female
# Email: o.cameron@randatmail.com
# Card Number: 187-73
# Fines: 0.0
# -------
# Member ID: 188
# Name: Sienna Bennett
# Gender: Female
# Email: s.bennett@randatmail.com
# Card Number: 188-81
# Fines: 0.0
# -------
# Member ID: 189
# Name: Victoria Howard
# Gender: Female
# Email: v.howard@randatmail.com
# Card Number: 189-91
# Fines: 0.0
# -------
# Member ID: 190
# Name: William West
# Gender: Male
# Email: w.west@randatmail.com
# Card Number: 190-1
# Fines: 0.0
# -------
# Member ID: 191
# Name: Fiona Alexander
# Gender: Female
# Email: f.alexander@randatmail.com
# Card Number: 191-13
# Fines: 0.0
# -------
# Member ID: 192
# Name: Kristian Walker
# Gender: Male
# Email: k.walker@randatmail.com
# Card Number: 192-22
# Fines: 0.0
# -------
# Member ID: 193
# Name: Naomi Higgins
# Gender: Female
# Email: n.higgins@randatmail.com
# Card Number: 193-31
# Fines: 0.0
# -------
# Member ID: 194
# Name: Stuart Mason
# Gender: Male
# Email: s.mason@randatmail.com
# Card Number: 194-43
# Fines: 0.0
# -------
# Member ID: 195
# Name: Brad Jones
# Gender: Male
# Email: b.jones@randatmail.com
# Card Number: 195-53
# Fines: 0.0
# -------
# Member ID: 196
# Name: Alexander Cooper
# Gender: Male
# Email: a.cooper@randatmail.com
# Card Number: 196-63
# Fines: 0.0
# -------
# Member ID: 197
# Name: Ned Ryan
# Gender: Male
# Email: n.ryan@randatmail.com
# Card Number: 197-72
# Fines: 0.0
# -------
# Member ID: 198
# Name: Audrey Murray
# Gender: Female
# Email: a.murray@randatmail.com
# Card Number: 0
# Fines: 0.0
# -------
# Member ID: 199
# Name: Caroline Anderson
# Gender: Female
# Email: c.anderson@randatmail.com
# Card Number: 199-91
# Fines: 0.0
# -------
# Member ID: 200
# Name: Marcus Parker
# Gender: Male
# Email: m.parker@randatmail.com
# Card Number: 200-2
# Fines: 0.0
# -------
